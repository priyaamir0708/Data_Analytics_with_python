# %% [markdown]
# Weight= 55
# print (Weight)

# %%
My_number = 73
print(My_number)   #integer
# Out:
# 73

# %%
# variables

number = 77

# %%
Weight = 55.6
print(Weight)
print(type(Weight))  #float
# Out:
# 55.6
# <class 'float'>

# %%
College = "Pope's college"
print(College)
print (type(College))
# Out:
# Pope's college
# <class 'str'>

# %%
56<120
print (type(56<120))
# Out:
# <class 'bool'>

# %%
77<10
print (type(77<10))
# Out:
# <class 'bool'>

# %%
Mark = 75

# %%
Mark >= 35
# Out:
# True

# %%
mark = 75
if mark >35:
    print ("pass")
else:
    print ("fail")
# Out:
# pass

# %%
age = 55

# %%
age >= 18
# Out:
# True

# %%
age = 55
if age >18:
    print ("eligible for voting ")
else:
    print (" Not eligible for voting ")
# Out:
# eligible for voting

# %%
marks = input("enter your marks")
print(type(marks))    # "26"

my_marks = int(input("enter your marks"))
print (type(my_marks))   # "26"
# Out:
# enter your marks26
# <class 'str'>
# enter your marks26
# <class 'int'>

# %%
marks = int(input("give the marks.. "))
if marks >=90 and marks<100:
   print ("gradeA")
elif marks >=80 and marks <90:
   print ("gradeB")
elif marks >=70 and marks <80:
   print ("gradeC")
elif marks >=60 and marks <70:
   print ("gradeD")
elif marks >=50 and marks <60:
   print ("gradeE")
else:
   print ("fail")
# Out:
# give the marks.. 77
# gradeC

# %%
my_marks =[ 55,85,92,93,50]
print (my_marks)
print(type(my_marks))
print (len(my_marks))  #length
print (my_marks[1])
print(my_marks[1:4]) #slice
# Out:
# [55, 85, 92, 93, 50]
# <class 'list'>
# 5
# 85
# [85, 92, 93]

# %%
new_li = ["dharshini", "asin","deepika", "aarthi"]
print(new_li)
# Out:
# ['dharshini', 'asin', 'deepika', 'aarthi']

# %%
for d in new_li:
   print (d)
# Out:
# dharshini
# asin
# deepika
# aarthi

# %%
marks = [ 95,83,86,81,79,64]
print (marks)
# Out:
# [95, 83, 86, 81, 79, 64]

# %%
for d in marks:
   print(d)
# Out:
# 95
# 83
# 86
# 81
# 79
# 64

# %%
for d in marks:
   print(d)
   if d >= 35:
     print ("passed")
     print("you have passed the exam, your score is",d)
   else:
     print ("failed",d, "marks score")
# Out:
# 95
# passed
# you have passed the exam, your score is 95
# 83
# passed
# you have passed the exam, your score is 83
# 86
# passed
# you have passed the exam, your score is 86
# 81
# passed
# you have passed the exam, your score is 81
# 79
# passed
# you have passed the exam, your score is 79
# 64
# passed
# you have passed the exam, your score is 64

# %%
li = [4,5,6,7,8,23]
print (li)
# Out:
# [4, 5, 6, 7, 8, 23]
